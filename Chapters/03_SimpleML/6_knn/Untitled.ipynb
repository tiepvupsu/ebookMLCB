# %%
import sklearn as sk
# Out:
#  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  --  -- -
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7e64a9fe2d7d> in <module>()
#  --  -- > 1 import sklearn as sk
#
# ImportError: No module named sklearn
