# %% [markdown]
# ## Ví dụ trên Python
# Khai báo các thư viện cần dùng.

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import random
np.random.seed(11)
from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# Tạo dữ liệu bằng cách lấy các điểm theo phân phối chuẩn có kỳ vọng tại `(2, 2), (8, 3)` và `(3, 6)`, ma trận hiệp phương sai giống nhau và là ma trận đơn vị. Mỗi cụm có 500 điểm. Hiển thị các cụm điểm trên đồ thị.

# %%
means = [[2, 2], [8, 3], [3, 6]]
cov = [[1, 0], [0, 1]]
N = 100
X0 = np.random.multivariate_normal(means[0], cov, N)
X1 = np.random.multivariate_normal(means[1], cov, N)
X2 = np.random.multivariate_normal(means[2], cov, N)

plt.plot(X0[:, 0], X0[:, 1], 'k^', markersize = 5, alpha = .8)
plt.plot(X1[:, 0], X1[:, 1], 'wx', mec = 'k', markersize = 6, alpha = .8)
plt.plot(X2[:, 0], X2[:, 1], 'ws', mec = 'k', markersize = 5, alpha = .8)
plt.axis('off')
plt.plot()
filename = 'dist1.pdf'
with PdfPages(filename) as pdf:
    pdf.savefig(bbox_inches='tight')
plt.show()

# %%
means = [[2, 2], [6, 2], [10, 2]]
cov = [[1, 0], [0, 1]]
N = 500
X0 = np.random.multivariate_normal(means[0], cov, N)
X1 = np.random.multivariate_normal(means[1], cov, N)
X2 = np.random.multivariate_normal(means[2], cov, N)

plt.plot(X0[:, 0], X0[:, 1], 'k^', markersize = 5, alpha = .8)
plt.plot(X1[:, 0], X1[:, 1], 'wx', mec = 'k', markersize = 6, alpha = .8)
plt.plot(X2[:, 0], X2[:, 1], 'ws', mec = 'k', markersize = 5, alpha = .8)

plt.axis('off')
plt.plot()
filename = 'dist2.pdf'
with PdfPages(filename) as pdf:
    pdf.savefig(bbox_inches='tight')

plt.show()

# %%
means = [[2, 2], [6, 2], [10, 2], [5, 7]]
cov = [[1, 0], [0, 1]]
N = 500
X0 = np.random.multivariate_normal(means[0], cov, N)
X1 = np.random.multivariate_normal(means[1], cov, N)
X2 = np.random.multivariate_normal(means[2], cov, N)
X3 = np.random.multivariate_normal(means[3], cov, N)

plt.plot(X0[:, 0], X0[:, 1], 'k^', markersize = 5, alpha = .8)
plt.plot(X1[:, 0], X1[:, 1], 'wx', mec = 'k', markersize = 6, alpha = .8)
plt.plot(X2[:, 0], X2[:, 1], 'ws', mec = 'k', markersize = 5, alpha = .8)
plt.plot(X3[:, 0], X3[:, 1], 'k+', markersize = 5, alpha = .8)
plt.axis('off')
plt.plot()
filename = 'dist3.pdf'
with PdfPages(filename) as pdf:
    pdf.savefig(bbox_inches='tight')

plt.show()
