# %%
import numpy as np
from scipy.spatial import ConvexHull
points = np.random.rand(15, 2)   # 30 random points in 2-D
hull = ConvexHull(points)

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.axis('off')

plt.plot(points[:,0], points[:,1], 'o')
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
    
plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'k', lw=1)

print(points)
print(hull.vertices)
# plt.xmin(-1)
# plt.xmax(2)
# plt.ymin(-1)
# plt.ymax(2)
# plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
plt.show()
# Out:
# [[ 0.36366863  0.99746902]
#  [ 0.52253463  0.41180361]
#  [ 0.01361061  0.26159076]
#  [ 0.1236619   0.64295637]
#  [ 0.5309096   0.0670372 ]
#  [ 0.53146543  0.0546566 ]
#  [ 0.9173887   0.75295094]
#  [ 0.4281914   0.69055756]
#  [ 0.3725817   0.15117274]
#  [ 0.69543098  0.41298839]
#  [ 0.087166    0.4343049 ]
#  [ 0.69392467  0.69367188]
#  [ 0.23184426  0.30297735]
#  [ 0.34797291  0.01007143]
#  [ 0.91948964  0.60904332]]
# [ 5 14  6  0  3  2 13]
